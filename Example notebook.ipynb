# %%
from fitter.sho_fitter import SHO_data
import matplotlib.pyplot as plt

# %%
A1=SHO_data(file='h5 filename',x=256,y=256)
A1.load_raw_data()
A1.create_model()
A1.load_weights(r"weights\model_130_1.h5")
A1.do_hybrid_fitting()
# Out:
# 100%|█| 65536/65536 [24:17<00:00, 44.95it/s]

# %%
plt.imshow(A1.hybrid_fit['phase'])

# %%
A1.do_DNN_fitting()
# Out:
# 100%|█| 65536/65536 [05:24<00:00, 202.10it/s]

# %%
plt.imshow(A1.DNN_fit['phase'])
